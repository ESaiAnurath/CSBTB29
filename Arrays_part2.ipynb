# %% [markdown]
# <a href="https://colab.research.google.com/github/E-SaiAnurath/CSBTB29/blob/main/Arrays_part2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Part 2 { Visualization of Data using matplotlib, pyplots Pack-
# ages[CO2]
# 1. Generate a Data set for Health Care using the following:
# people = ['kiran', arun', 'vijay', 'varun']
# age =[25, 30, 35, 40, 45]
# height =[145, 151, 165, 173]
# weight=[45, 55, 65, 75]
# 2. Using the generated dataset given above. Generate the following graphs and justify the
# relationships among the vectors.
# 3. Scatter Plot
# 4. Bar Chart
# 5. Histogram
# 6. Provide Graph Title, labels for X, Y axis with proper justi cation and explanation of
# the graph.

# %%
import matplotlib.pyplot as plt
people = ['Kiran', 'Arun', 'Vijay', 'Varun']
age = [25, 30, 35, 40]
height = [150, 151, 170, 200]
weight = [55, 65, 85, 95]

# %%
import matplotlib.pyplot as plt

plt.scatter(height, weight)
plt.title('Scatter Plot: Height vs Weight')
plt.xlabel('Height (cm)')
plt.ylabel('Weight (kg)')
plt.show()

# %%
plt.bar(people, height, color='blue')
plt.title('Bar Chart: Height of People')
plt.xlabel('People')
plt.ylabel('Height (cm)')
plt.show()

# %%
plt.hist(age, bins=5, color='green')
plt.title('Histogram: Age Distribution')
plt.xlabel('Age (years)')
plt.ylabel('Frequency')
plt.show()
